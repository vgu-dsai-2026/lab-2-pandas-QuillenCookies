# %% [markdown]
# # Basic pandas
#
# In this notebook, we will learn the most useful pandas ideas for data science and machine learning.
#
# You will practice:
# - creating DataFrames
# - selecting and filtering rows
# - working with columns
# - grouping and summarizing data
# - reading from and saving to CSV files

# %% [markdown]
# ## What is pandas?
#
# pandas is a Python library for working with tabular data.
#
# A table in pandas is called a **DataFrame**.
#
# A single column in a DataFrame is called a **Series**.

# %%
import pandas as pd

# %% [markdown]
# ## Create a simple DataFrame
#
# We start with a small example table so we can see the basic structure clearly.

# %%
data = {
    "name": ["cat_1", "dog_1", "cat_2", "dog_2"],
    "label": ["cat", "dog", "cat", "dog"],
    "score": [0.91, 0.12, 0.85, 0.33]
}

df = pd.DataFrame(data)
print(df)
# Out:
#     name label  score
# 0  cat_1   cat   0.91
# 1  dog_1   dog   0.12
# 2  cat_2   cat   0.85
# 3  dog_2   dog   0.33

# %%
# Check the shape of the table.
# This tells us how many rows and columns there are.

print("Shape:", df.shape)
# Out:
# Shape: (4, 3)

# %%
# Show the column names.

print("Columns:", df.columns)
# Out:
# Columns: Index(['name', 'label', 'score'], dtype='str')

# %%
# Look at the data types of each column.

print(df.dtypes)
# Out:
# name         str
# label        str
# score    float64
# dtype: object

# %% [markdown]
# ## Select columns
#
# In pandas, we can access one column or multiple columns easily.

# %%
# Select one column.
# The result is a pandas Series.

print(df["label"])
# Out:
# 0    cat
# 1    dog
# 2    cat
# 3    dog
# Name: label, dtype: str

# %%
# Select multiple columns.
# The result is a DataFrame.

print(df[["name", "score"]])
# Out:
#     name  score
# 0  cat_1   0.91
# 1  dog_1   0.12
# 2  cat_2   0.85
# 3  dog_2   0.33

# %% [markdown]
# ## Select rows
#
# We often want only some rows, not the entire table.

# %%
# Select the first two rows.

print(df.head(2))
# Out:
#     name label  score
# 0  cat_1   cat   0.91
# 1  dog_1   dog   0.12

# %%
# Select a row by integer position.

print(df.iloc[1])
# Out:
# name     dog_1
# label      dog
# score     0.12
# Name: 1, dtype: object

# %% [markdown]
# ## Filtering rows
#
# Filtering means keeping only rows that satisfy a condition.
# This is one of the most important pandas skills for machine learning.

# %%
# Keep only rows where the label is cat.

cat_rows = df[df["label"] == "cat"]
print(cat_rows)
# Out:
#     name label  score
# 0  cat_1   cat   0.91
# 2  cat_2   cat   0.85

# %%
# Keep only rows where the score is greater than 0.5.

high_score_rows = df[df["score"] > 0.5]
print(high_score_rows)
# Out:
#     name label  score
# 0  cat_1   cat   0.91
# 2  cat_2   cat   0.85

# %% [markdown]
# ## Add or modify columns
#
# pandas makes it easy to create new columns from existing ones.

# %%
# Create a new boolean column that says whether the score is high.

df["high_score"] = df["score"] > 0.5
print(df)
# Out:
#     name label  score  high_score
# 0  cat_1   cat   0.91        True
# 1  dog_1   dog   0.12       False
# 2  cat_2   cat   0.85        True
# 3  dog_2   dog   0.33       False

# %%
# Create a new column using a simple rule.

df["score_scaled"] = df["score"] * 100
print(df)
# Out:
#     name label  score  high_score  score_scaled
# 0  cat_1   cat   0.91        True          91.0
# 1  dog_1   dog   0.12       False          12.0
# 2  cat_2   cat   0.85        True          85.0
# 3  dog_2   dog   0.33       False          33.0

# %% [markdown]
# ## Sorting
#
# Sorting is useful when we want to rank examples by a score.

# %%
# Sort by score from largest to smallest.

sorted_df = df.sort_values("score", ascending=False)
print(sorted_df)
# Out:
#     name label  score  high_score  score_scaled
# 0  cat_1   cat   0.91        True          91.0
# 2  cat_2   cat   0.85        True          85.0
# 3  dog_2   dog   0.33       False          33.0
# 1  dog_1   dog   0.12       False          12.0

# %% [markdown]
# ## Grouping and summarizing
#
# Grouping helps us compute summaries for each class.
# This is useful when checking balance between cat and dog examples.

# %%
# Compute the average score for each label.

group_mean = df.groupby("label")["score"].mean()
print(group_mean)
# Out:
# label
# cat    0.880
# dog    0.225
# Name: score, dtype: float64

# %%
# Count how many rows belong to each label.

group_count = df.groupby("label").size()
print(group_count)
# Out:
# label
# cat    2
# dog    2
# dtype: int64

# %% [markdown]
# ## Read and write CSV files
#
# We often store predictions, labels, and metadata in CSV files.

# %%
# Save the small table to CSV.

df.to_csv("example.csv", index=False)
print("Saved example.csv")
# Out:
# Saved example.csv

# %%
# Read it back from disk.

df_loaded = pd.read_csv("example.csv")
print(df_loaded)
# Out:
#     name label  score  high_score  score_scaled
# 0  cat_1   cat   0.91        True          91.0
# 1  dog_1   dog   0.12       False          12.0
# 2  cat_2   cat   0.85        True          85.0
# 3  dog_2   dog   0.33       False          33.0

# %% [markdown]
# # Standard EDA Flow for Tabular Data
#
# EDA means **Exploratory Data Analysis**.
#
# EDA can be applied to a wide range of problems and data types; however, this tutorial will focus solely on tabular data.
#
# Before building any model, we should understand the table carefully:
# - how big it is
# - what each column means
# - whether there are missing values
# - whether categories are balanced
# - whether there are outliers
# - whether the numerical columns look reasonable
#
# Good EDA helps us avoid mistakes later.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Make plots easier to read in notebooks.
plt.rcParams["figure.figsize"] = (8, 4)
plt.rcParams["axes.grid"] = True

# %% [markdown]
# ## Step 1: Load the data
#
# In a real project, the first step is usually to read a CSV file or load a table from a database.
#
# For this tutorial, we will use a small example DataFrame so you can change the data to explore further.

# %%
# Example tabular dataset with both numeric and categorical columns.
# We also include a missing value and a duplicate row to make the EDA more realistic.

df = pd.DataFrame({
    "student_id": [1, 2, 3, 4, 5, 6, 6, 7, 8],
    "age": [18, 19, 18, 50, 19, np.nan, np.nan, 20, 21],
    "study_hours": [2.5, 3.0, 1.0, 4.5, 2.0, 5.0, 5.0, 10.0, np.nan],
    "score": [72, 80, 85, 91, 68, 95, 95, 15, 88],
    "major": ["CS", "Math", "CS", "Physics", "Math", "CS", "CS", "CS", "Math"]
})

df
# Out:
#    student_id   age  study_hours  score    major
# 0           1  18.0          2.5     72       CS
# 1           2  19.0          3.0     80     Math
# 2           3  18.0          1.0     85       CS
# 3           4  50.0          4.5     91  Physics
# 4           5  19.0          2.0     68     Math
# 5           6   NaN          5.0     95       CS
# 6           6   NaN          5.0     95       CS
# 7           7  20.0         10.0     15       CS
# 8           8  21.0          NaN     88     Math

# %% [markdown]
# ## Step 2: Check the shape and preview the first rows
#
# This tells us:
# - how many rows and columns there are
# - what the data looks like at a glance
# - whether the column names make sense

# %%
print("Shape:", df.shape)
print("Columns:", df.columns.tolist())
print("\nFirst few rows:")
display(df.head())
# Out:
# Shape: (9, 5)
# Columns: ['student_id', 'age', 'study_hours', 'score', 'major']
#
# First few rows:
#    student_id   age  study_hours  score    major
# 0           1  18.0          2.5     72       CS
# 1           2  19.0          3.0     80     Math
# 2           3  18.0          1.0     85       CS
# 3           4  50.0          4.5     91  Physics
# 4           5  19.0          2.0     68     Math

# %%
# We can extract general information about the dataframe using info()
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   9 non-null      int64
#  1   age          7 non-null      float64
#  2   study_hours  8 non-null      float64
#  3   score        9 non-null      int64
#  4   major        9 non-null      str
# dtypes: float64(2), int64(2), str(1)
# memory usage: 492.0 bytes
# None

# %% [markdown]
# ## Step 3: Check column types and non-missing counts
#
# This helps us see:
# - which columns are numeric
# - which columns are categorical
# - where missing values may exist

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 9 entries, 0 to 8
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   student_id   9 non-null      int64
#  1   age          7 non-null      float64
#  2   study_hours  8 non-null      float64
#  3   score        9 non-null      int64
#  4   major        9 non-null      str
# dtypes: float64(2), int64(2), str(1)
# memory usage: 492.0 bytes

# %% [markdown]
# ## Step 4: Clean missing values and duplicate rows
#
# Real-world data is often messy.
#
# Two common issues are:
# - **Missing values** (NaN)
# - **Duplicate rows**
#
# We usually:
# 1. Detect them
# 2. Decide how to handle them
# 3. Remove or fix them
#
# For this tutorial, we will:
# - drop duplicate rows
# - remove rows with missing values
#
# In practice, you may choose more advanced strategies (e.g., filling missing values instead of dropping).

# %%
# Check results
print("\nBefore cleaning shape:", df.shape)

print("\nRemaining missing values:")
print(df.isna().sum())

print("\nRemaining duplicates:", df.duplicated().sum())
# Out:
# Before cleaning shape: (9, 5)
#
# Remaining missing values:
# student_id     0
# age            2
# study_hours    1
# score          0
# major          0
# dtype: int64
#
# Remaining duplicates: 1

# %%
# Remove duplicate rows
df_clean = df.drop_duplicates()

# Remove rows with missing values
df_clean = df_clean.dropna()


# Check results
print("\nAfter cleaning shape:", df_clean.shape)

print("\nRemaining missing values:")
print(df_clean.isna().sum())

print("\nRemaining duplicates:", df_clean.duplicated().sum())

# It is recommended to use .copy() to create a separate independent object
df = df_clean.copy()
# Out:
# After cleaning shape: (6, 5)
#
# Remaining missing values:
# student_id     0
# age            0
# study_hours    0
# score          0
# major          0
# dtype: int64
#
# Remaining duplicates: 0

# %% [markdown]
# ## Step 5: Summary statistics
#
# Use summary statistics to understand the distribution of numeric columns.
#
# For categorical columns, use value counts to check the class balance.

# %%
print("Numeric summary:")
display(df.describe())

print("\nCategorical summary:")
display(df["major"].value_counts())
# Out:
# Numeric summary:
#        student_id       age  study_hours     score
# count    6.000000   6.00000     6.000000   6.00000
# mean     3.666667  24.00000     3.833333  68.50000
# std      2.160247  12.75931     3.235223  27.51545
# min      1.000000  18.00000     1.000000  15.00000
# 25%      2.250000  18.25000     2.125000  69.00000
# 50%      3.500000  19.00000     2.750000  76.00000
# 75%      4.750000  19.75000     4.125000  83.75000
# max      7.000000  50.00000    10.000000  91.00000
# Categorical summary:
# major
# CS         3
# Math       2
# Physics    1
# Name: count, dtype: int64

# %% [markdown]
# ## Step 6: Look at one variable at a time
#
# An EDA workflow may include simple plots to inspect the distribution of one variable:
# - histograms for numeric columns
# - bar charts for categorical columns
#
# These plots can reveal skew, imbalance, and outliers.

# %%
fig, axes = plt.subplots(1, 2, figsize=(10, 4))

# Histogram for a numeric column (score)
axes[0].hist(df["score"].dropna(), bins=5)
axes[0].set_title("Score distribution")
axes[0].set_xlabel("score")
axes[0].set_ylabel("count")

# Bar chart for a categorical column (major)
df["major"].value_counts().plot(kind="bar", ax=axes[1])
axes[1].set_title("Major counts")
axes[1].set_xlabel("major")
axes[1].set_ylabel("count")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 7: Compare variables to each other
#
# Now we look at the correlations between columns.
#
# For tabular data, some common questions are:
# - Does A relate to B? (*numeric* vs *numeric*)
# - Are some categories in column C associated with higher values in column D? (*categorical* vs *numeric*)

# %%
# Scatter plot for two numeric columns.
plt.figure(figsize=(6, 4))
plt.scatter(df["study_hours"], df["score"])
plt.title("Study hours vs score")
plt.xlabel("study_hours")
plt.ylabel("score")
plt.show()

# %%
# Correlation matrix for numeric columns.

numeric_df = df[["age", "study_hours", "score"]]
corr = numeric_df.corr()

plt.figure(figsize=(5, 4))
plt.imshow(corr, cmap="coolwarm", interpolation="nearest")
plt.colorbar(label="correlation")
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.index)), corr.index)
plt.title("Correlation heatmap")
plt.tight_layout()
plt.show()

display(corr)
# Out:
#                   age  study_hours     score
# age          1.000000     0.150197  0.355476
# study_hours  0.150197     1.000000 -0.842520
# score        0.355476    -0.842520  1.000000

# %% [markdown]
# ## Step 8: Detect outliers with box plots
#
# A **box plot** is one of the best tools to detect outliers.
#
# It shows:
# - median (middle value)
# - quartiles (spread of the data)
# - potential outliers (points far away from the rest)
#
# Outliers are usually values that are much larger or smaller than the majority of the data.

# %%
# Create a box plot for numeric columns.

numeric_cols = ["age", "study_hours", "score"]

plt.figure(figsize=(8, 4))
df[numeric_cols].boxplot()

plt.title("Box plot for numeric features")
plt.ylabel("value")
plt.show()

# %% [markdown]
# ## How to read the box plot
#
# - The **box** shows the middle 50% of the data (interquartile range)
# - The **line inside the box** is the median
# - The **whiskers** extend within 1.5 × IQR from Q1 and Q3, showing variability outside the middle 50%.
# - Points outside the whiskers are **potential outliers**
#
# If you see points far away from the box, investigate them.

# %%
# Look at one column more closely.

plt.figure(figsize=(6, 4))
plt.boxplot(df["score"].dropna())

plt.title("Box plot of score")
plt.ylabel("score")
plt.show()

# %%
# Identify outliers for "score" column using the IQR rule

Q1 = df["score"].quantile(0.25)
Q3 = df["score"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Any value below the lower bound or above the upper bound is a outlier
outliers = df[(df["score"] < lower_bound) | (df["score"] > upper_bound)]

print("Lower bound:", lower_bound)
print("Upper bound:", upper_bound)

print("\nPotential outliers:")
display(outliers)
# Out:
# Lower bound: 46.875
# Upper bound: 105.875
#
# Potential outliers:
#    student_id   age  study_hours  score major
# 7           7  20.0         10.0     15    CS

# %% [markdown]
# ## Why plotting matters - a Datasaurus Dozen example
#
# The Datasaurus Dozen is a famous reminder that different datasets can have very similar summary statistics, even though their shapes are completely different.
#
# That means:
# - mean may look the same
# - standard deviation may look similar
# - correlation may look similar
#
# But the plot can tell a very different story.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load the CSV file.
# Adjust the path if needed.
df = pd.read_csv("labs/datasaurus.csv")

print("Shape:", df.shape)
display(df.head())
# Out:
# . ['.gitignore', '.python-version', 'basic_notebook.ipynb', 'example.csv', 'notebook.ipynb', 'pyproject.toml', 'README.md', 'uv.lock']
# .\.devcontainer ['devcontainer.json']
# .\.git ['config', 'description', 'HEAD', 'index', 'packed-refs']
# .\.git\hooks ['applypatch-msg.sample', 'commit-msg.sample', 'fsmonitor-watchman.sample', 'post-update.sample', 'pre-applypatch.sample', 'pre-commit.sample', 'pre-merge-commit.sample', 'pre-push.sample', 'pre-rebase.sample', 'pre-receive.sample', 'prepare-commit-msg.sample', 'push-to-checkout.sample', 'sendemail-validate.sample', 'update.sample']
# .\.git\info ['exclude']
# .\.git\logs ['HEAD']
# .\.git\logs\refs []
# .\.git\logs\refs\heads ['main']
# .\.git\logs\refs\remotes []
# .\.git\logs\refs\remotes\origin ['HEAD']
# .\.git\objects []
# .\.git\objects\info []
# .\.git\objects\pack ['pack-28130f7c25624b7880a835949232dfe75133d7fa.idx', 'pack-28130f7c25624b7880a835949232dfe75133d7fa.pack', 'pack-28130f7c25624b7880a835949232dfe75133d7fa.rev']
# .\.git\refs []
# .\.git\refs\heads ['main']
# .\.git\refs\remotes []
# .\.git\refs\remotes\origin ['HEAD']
# .\.git\refs\tags []
# .\.github ['.keep']
# .\.github\workflows ['classroom.yml']
# .\.venv ['.gitignore', '.lock', 'CACHEDIR.TAG', 'pyvenv.cfg']
# .\.venv\Lib []
# .\.venv\Lib\site-packages ['decorator.py', 'distutils-precedence.pth', 'ipykernel_launcher.py', 'ipython_pygments_lexers.py', 'isympy.py', 'jupyter.py', 'nest_asyncio.py', 'pandocfilters.py', 'py.py', 'pylab.py', 'six.py', 'typing_extensions.py', '_virtualenv.pth', '_virtualenv.py']
# .\.venv\Lib\site-packages\asttokens ['astroid_compat.py', 'asttokens.py', 'line_numbers.py', 'mark_tokens.py', 'py.typed', 'util.py', 'version.py', '__init__.py']
# .\.venv\Lib\site-packages\asttokens\__pycache__ ['asttokens.cpython-311.pyc', 'line_numbers.cpython-311.pyc', 'util.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\asttokens-3.0.1.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\asttokens-3.0.1.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\attr ['converters.py', 'converters.pyi', 'exceptions.py', 'exceptions.pyi', 'filters.py', 'filters.pyi', 'py.typed', 'setters.py', 'setters.pyi', 'validators.py', 'validators.pyi', '_cmp.py', '_cmp.pyi', '_compat.py', '_config.py', '_funcs.py', '_make.py', '_next_gen.py', '_typing_compat.pyi', '_version_info.py', '_version_info.pyi', '__init__.py', '__init__.pyi']
# .\.venv\Lib\site-packages\attrs ['converters.py', 'exceptions.py', 'filters.py', 'py.typed', 'setters.py', 'validators.py', '__init__.py', '__init__.pyi']
# .\.venv\Lib\site-packages\attrs-26.1.0.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'WHEEL']
# .\.venv\Lib\site-packages\attrs-26.1.0.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\beautifulsoup4-4.14.3.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'WHEEL']
# .\.venv\Lib\site-packages\beautifulsoup4-4.14.3.dist-info\licenses ['AUTHORS', 'LICENSE']
# .\.venv\Lib\site-packages\bleach ['callbacks.py', 'css_sanitizer.py', 'html5lib_shim.py', 'linkifier.py', 'parse_shim.py', 'sanitizer.py', 'six_shim.py', '__init__.py']
# .\.venv\Lib\site-packages\bleach\_vendor ['parse.py', 'parse.py.SHA256SUM', 'README.rst', 'vendor.txt', 'vendor_install.sh', '__init__.py']
# .\.venv\Lib\site-packages\bleach\_vendor\html5lib ['constants.py', 'html5parser.py', 'serializer.py', '_ihatexml.py', '_inputstream.py', '_tokenizer.py', '_utils.py', '__init__.py']
# .\.venv\Lib\site-packages\bleach\_vendor\html5lib\filters ['alphabeticalattributes.py', 'base.py', 'inject_meta_charset.py', 'lint.py', 'optionaltags.py', 'sanitizer.py', 'whitespace.py', '__init__.py']
# .\.venv\Lib\site-packages\bleach\_vendor\html5lib\treeadapters ['genshi.py', 'sax.py', '__init__.py']
# .\.venv\Lib\site-packages\bleach\_vendor\html5lib\treebuilders ['base.py', 'dom.py', 'etree.py', 'etree_lxml.py', '__init__.py']
# .\.venv\Lib\site-packages\bleach\_vendor\html5lib\treewalkers ['base.py', 'dom.py', 'etree.py', 'etree_lxml.py', 'genshi.py', '__init__.py']
# .\.venv\Lib\site-packages\bleach\_vendor\html5lib\_trie ['py.py', '_base.py', '__init__.py']
# .\.venv\Lib\site-packages\bleach\_vendor\html5lib-1.1.dist-info ['AUTHORS.rst', 'INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\bleach-6.3.0.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\bleach-6.3.0.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\bleach-6.3.0.dist-info\licenses\bleach []
# .\.venv\Lib\site-packages\bleach-6.3.0.dist-info\licenses\bleach\_vendor []
# .\.venv\Lib\site-packages\bleach-6.3.0.dist-info\licenses\bleach\_vendor\html5lib-1.1.dist-info ['LICENSE']
# .\.venv\Lib\site-packages\bs4 ['css.py', 'dammit.py', 'diagnose.py', 'element.py', 'exceptions.py', 'filter.py', 'formatter.py', 'py.typed', '_deprecation.py', '_typing.py', '_warnings.py', '__init__.py']
# .\.venv\Lib\site-packages\bs4\builder ['_html5lib.py', '_htmlparser.py', '_lxml.py', '__init__.py']
# .\.venv\Lib\site-packages\colorama ['ansi.py', 'ansitowin32.py', 'initialise.py', 'win32.py', 'winterm.py', '__init__.py']
# .\.venv\Lib\site-packages\colorama\tests ['ansitowin32_test.py', 'ansi_test.py', 'initialise_test.py', 'isatty_test.py', 'utils.py', 'winterm_test.py', '__init__.py']
# .\.venv\Lib\site-packages\colorama\__pycache__ ['ansi.cpython-311.pyc', 'ansitowin32.cpython-311.pyc', 'initialise.cpython-311.pyc', 'win32.cpython-311.pyc', 'winterm.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\colorama-0.4.6.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'WHEEL']
# .\.venv\Lib\site-packages\colorama-0.4.6.dist-info\licenses ['LICENSE.txt']
# .\.venv\Lib\site-packages\comm ['base_comm.py', 'py.typed', '__init__.py']
# .\.venv\Lib\site-packages\comm\__pycache__ ['base_comm.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\comm-0.2.3.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'WHEEL']
# .\.venv\Lib\site-packages\comm-0.2.3.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\contourpy ['array.py', 'chunk.py', 'convert.py', 'dechunk.py', 'enum_util.py', 'py.typed', 'typecheck.py', 'types.py', '_contourpy.cp311-win_amd64.lib', '_contourpy.cp311-win_amd64.pyd', '_contourpy.pyi', '_version.py', '__init__.py']
# .\.venv\Lib\site-packages\contourpy\util ['bokeh_renderer.py', 'bokeh_util.py', 'data.py', 'mpl_renderer.py', 'mpl_util.py', 'renderer.py', '_build_config.py', '__init__.py']
# .\.venv\Lib\site-packages\contourpy-1.3.3.dist-info ['INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'REQUESTED', 'WHEEL']
# .\.venv\Lib\site-packages\cycler ['py.typed', '__init__.py']
# .\.venv\Lib\site-packages\cycler\__pycache__ ['__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\cycler-0.12.1.dist-info ['INSTALLER', 'LICENSE', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\dateutil ['easter.py', 'relativedelta.py', 'rrule.py', 'tzwin.py', 'utils.py', '_common.py', '_version.py', '__init__.py']
# .\.venv\Lib\site-packages\dateutil\parser ['isoparser.py', '_parser.py', '__init__.py']
# .\.venv\Lib\site-packages\dateutil\parser\__pycache__ ['isoparser.cpython-311.pyc', '_parser.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\dateutil\tz ['tz.py', 'win.py', '_common.py', '_factories.py', '__init__.py']
# .\.venv\Lib\site-packages\dateutil\tz\__pycache__ ['tz.cpython-311.pyc', 'win.cpython-311.pyc', '_common.cpython-311.pyc', '_factories.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\dateutil\zoneinfo ['dateutil-zoneinfo.tar.gz', 'rebuild.py', '__init__.py']
# .\.venv\Lib\site-packages\dateutil\__pycache__ ['easter.cpython-311.pyc', 'relativedelta.cpython-311.pyc', 'rrule.cpython-311.pyc', '_common.cpython-311.pyc', '_version.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\debugpy ['public_api.py', 'py.typed', 'ThirdPartyNotices.txt', '_version.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\debugpy\adapter ['clients.py', 'components.py', 'launchers.py', 'servers.py', 'sessions.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\debugpy\adapter\__pycache__ ['__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\debugpy\common ['json.py', 'log.py', 'messaging.py', 'singleton.py', 'sockets.py', 'stacks.py', 'timestamp.py', 'util.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\common\__pycache__ ['json.cpython-311.pyc', 'log.cpython-311.pyc', 'sockets.cpython-311.pyc', 'timestamp.cpython-311.pyc', 'util.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\debugpy\launcher ['debuggee.py', 'handlers.py', 'output.py', 'winapi.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\debugpy\server ['api.py', 'attach_pid_injected.py', 'cli.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\server\__pycache__ ['api.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\debugpy\_vendored ['force_pydevd.py', '_pydevd_packaging.py', '_util.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd ['pydevconsole.py', 'pydevd.py', 'pydevd_file_utils.py', 'pydevd_tracing.py', 'pydev_app_engine_debug_startup.py', 'pydev_coverage.py', 'pydev_pysrc.py', 'pydev_run_in_console.py', 'setup_pydevd_cython.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process ['add_code_to_python_process.py', 'attach_amd64.dll', 'attach_amd64.pdb', 'attach_pydevd.py', 'attach_script.py', 'attach_x86.dll', 'attach_x86.pdb', 'inject_dll_amd64.exe', 'inject_dll_amd64.pdb', 'inject_dll_x86.exe', 'inject_dll_x86.pdb', 'README.txt', 'run_code_on_dllmain_amd64.dll', 'run_code_on_dllmain_amd64.pdb', 'run_code_on_dllmain_x86.dll', 'run_code_on_dllmain_x86.pdb', '_always_live_program.py', '_check.py', '_test_attach_to_process.py', '_test_attach_to_process_linux.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\common ['python.h', 'py_custom_pyeval_settrace.hpp', 'py_custom_pyeval_settrace_310.hpp', 'py_custom_pyeval_settrace_311.hpp', 'py_custom_pyeval_settrace_common.hpp', 'py_settrace.hpp', 'py_utils.hpp', 'py_version.hpp', 'ref_utils.hpp']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\linux_and_mac ['.gitignore', 'attach.cpp', 'compile_linux.sh', 'compile_mac.sh', 'compile_manylinux.cmd', 'lldb_prepare.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\winappdbg ['breakpoint.py', 'compat.py', 'crash.py', 'debug.py', 'disasm.py', 'event.py', 'interactive.py', 'module.py', 'process.py', 'registry.py', 'search.py', 'sql.py', 'system.py', 'textio.py', 'thread.py', 'util.py', 'window.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\winappdbg\win32 ['advapi32.py', 'context_amd64.py', 'context_i386.py', 'dbghelp.py', 'defines.py', 'gdi32.py', 'kernel32.py', 'ntdll.py', 'peb_teb.py', 'psapi.py', 'shell32.py', 'shlwapi.py', 'user32.py', 'version.py', 'wtsapi32.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_attach_to_process\windows ['attach.cpp', 'attach.h', 'compile_windows.bat', 'inject_dll.cpp', 'py_win_helpers.hpp', 'run_code_in_memory.hpp', 'run_code_on_dllmain.cpp', 'stdafx.cpp', 'stdafx.h', 'targetver.h']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins ['django_debug.py', 'jinja2_debug.py', 'pydevd_line_validation.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\extensions ['README.md', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\extensions\types ['pydevd_helpers.py', 'pydevd_plugins_django_form_str.py', 'pydevd_plugin_numpy_types.py', 'pydevd_plugin_pandas_types.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\extensions\types\__pycache__ ['pydevd_helpers.cpython-311.pyc', 'pydevd_plugins_django_form_str.cpython-311.pyc', 'pydevd_plugin_numpy_types.cpython-311.pyc', 'pydevd_plugin_pandas_types.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\extensions\__pycache__ ['__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydevd_plugins\__pycache__ ['django_debug.cpython-311.pyc', 'jinja2_debug.cpython-311.pyc', 'pydevd_line_validation.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydev_ipython ['inputhook.py', 'inputhookglut.py', 'inputhookgtk.py', 'inputhookgtk3.py', 'inputhookpyglet.py', 'inputhookqt4.py', 'inputhookqt5.py', 'inputhookqt6.py', 'inputhooktk.py', 'inputhookwx.py', 'matplotlibtools.py', 'qt.py', 'qt_for_kernel.py', 'qt_loaders.py', 'README', 'version.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydev_ipython\__pycache__ ['__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\pydev_sitecustomize ['sitecustomize.py', '__not_in_default_pythonpath.txt']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle ['pydevconsole_code.py', 'pydevd_additional_thread_info.py', 'pydevd_additional_thread_info_regular.py', 'pydevd_api.py', 'pydevd_breakpoints.py', 'pydevd_bytecode_utils.py', 'pydevd_bytecode_utils_py311.py', 'pydevd_code_to_source.py', 'pydevd_collect_bytecode_info.py', 'pydevd_comm.py', 'pydevd_command_line_handling.py', 'pydevd_comm_constants.py', 'pydevd_console.py', 'pydevd_constants.py', 'pydevd_custom_frames.py', 'pydevd_cython.c', 'pydevd_cython.cp311-win_amd64.pyd', 'pydevd_cython.pxd', 'pydevd_cython.pyx', 'pydevd_cython_wrapper.py', 'pydevd_daemon_thread.py', 'pydevd_defaults.py', 'pydevd_dont_trace.py', 'pydevd_dont_trace_files.py', 'pydevd_exec2.py', 'pydevd_extension_api.py', 'pydevd_extension_utils.py', 'pydevd_filtering.py', 'pydevd_frame.py', 'pydevd_frame_utils.py', 'pydevd_gevent_integration.py', 'pydevd_import_class.py', 'pydevd_io.py', 'pydevd_json_debug_options.py', 'pydevd_net_command.py', 'pydevd_net_command_factory_json.py', 'pydevd_net_command_factory_xml.py', 'pydevd_plugin_utils.py', 'pydevd_process_net_command.py', 'pydevd_process_net_command_json.py', 'pydevd_referrers.py', 'pydevd_reload.py', 'pydevd_resolver.py', 'pydevd_runpy.py', 'pydevd_safe_repr.py', 'pydevd_save_locals.py', 'pydevd_signature.py', 'pydevd_source_mapping.py', 'pydevd_stackless.py', 'pydevd_suspended_frames.py', 'pydevd_thread_lifecycle.py', 'pydevd_timeout.py', 'pydevd_traceproperty.py', 'pydevd_trace_dispatch.py', 'pydevd_trace_dispatch_regular.py', 'pydevd_utils.py', 'pydevd_vars.py', 'pydevd_vm_type.py', 'pydevd_xml.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_concurrency_analyser ['pydevd_concurrency_logger.py', 'pydevd_thread_wrappers.py', '__init__.py']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle\pydevd_concurrency_analyser\__pycache__ ['pydevd_concurrency_logger.cpython-311.pyc', 'pydevd_thread_wrappers.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\debugpy\_vendored\pydevd\_pydevd_bundle
STALLER', 'LICENSE', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\executing ['executing.py', 'py.typed', 'version.py', '_exceptions.py', '_position_node_finder.py', '_pytest_utils.py', '_utils.py', '__init__.py']
# .\.venv\Lib\site-packages\executing\__pycache__ ['executing.cpython-311.pyc', 'version.cpython-311.pyc', '_exceptions.cpython-311.pyc', '_position_node_finder.cpython-311.pyc', '_pytest_utils.cpython-311.pyc', '_utils.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\executing-2.2.1.dist-info ['INSTALLER', 'LICENSE.txt', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\fastjsonschema ['draft04.py', 'draft06.py', 'draft07.py', 'exceptions.py', 'generator.py', 'indent.py', 'ref_resolver.py', 'version.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fastjsonschema-2.21.2.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\fastjsonschema-2.21.2.dist-info\licenses ['AUTHORS', 'LICENSE']
# .\.venv\Lib\site-packages\filelock ['asyncio.py', 'py.typed', 'version.py', '_api.py', '_async_read_write.py', '_error.py', '_read_write.py', '_soft.py', '_unix.py', '_util.py', '_windows.py', '__init__.py']
# .\.venv\Lib\site-packages\filelock-3.25.2.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'WHEEL']
# .\.venv\Lib\site-packages\filelock-3.25.2.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\fontTools ['afmLib.py', 'agl.py', 'annotations.py', 'fontBuilder.py', 'help.py', 'tfmLib.py', 'ttx.py', 'unicode.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\cffLib ['CFF2ToCFF.py', 'CFFToCFF2.py', 'specializer.py', 'transforms.py', 'width.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\colorLib ['builder.py', 'errors.py', 'geometry.py', 'table_builder.py', 'unbuilder.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\config ['__init__.py']
# .\.venv\Lib\site-packages\fontTools\cu2qu ['benchmark.py', 'cli.py', 'cu2qu.c', 'cu2qu.cp311-win_amd64.pyd', 'cu2qu.py', 'errors.py', 'ufo.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\designspaceLib ['split.py', 'statNames.py', 'types.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\diff ['color.py', 'diff.py', 'utils.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\encodings ['codecs.py', 'MacRoman.py', 'StandardEncoding.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\feaLib ['ast.py', 'builder.py', 'error.py', 'lexer.c', 'lexer.cp311-win_amd64.pyd', 'lexer.py', 'location.py', 'lookupDebugInfo.py', 'parser.py', 'variableScalar.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\merge ['base.py', 'cmap.py', 'layout.py', 'options.py', 'tables.py', 'unicode.py', 'util.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\misc ['arrayTools.py', 'bezierTools.c', 'bezierTools.cp311-win_amd64.pyd', 'bezierTools.py', 'classifyTools.py', 'cliTools.py', 'configTools.py', 'cython.py', 'dictTools.py', 'eexec.py', 'encodingTools.py', 'enumTools.py', 'etree.py', 'filenames.py', 'fixedTools.py', 'intTools.py', 'iterTools.py', 'lazyTools.py', 'loggingTools.py', 'macCreatorType.py', 'macRes.py', 'psCharStrings.py', 'psLib.py', 'psOperators.py', 'py23.py', 'roundTools.py', 'sstruct.py', 'symfont.py', 'testTools.py', 'textTools.py', 'timeTools.py', 'transform.py', 'treeTools.py', 'vector.py', 'visitor.py', 'xmlReader.py', 'xmlWriter.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\misc\filesystem ['_base.py', '_copy.py', '_errors.py', '_info.py', '_osfs.py', '_path.py', '_subfs.py', '_tempfs.py', '_tools.py', '_walk.py', '_zipfs.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\misc\plistlib ['py.typed', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\mtiLib ['__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\otlLib ['builder.py', 'error.py', 'maxContextCalc.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\otlLib\optimize ['gpos.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\pens ['areaPen.py', 'basePen.py', 'boundsPen.py', 'cairoPen.py', 'cocoaPen.py', 'cu2quPen.py', 'explicitClosingLinePen.py', 'filterPen.py', 'freetypePen.py', 'hashPointPen.py', 'momentsPen.c', 'momentsPen.cp311-win_amd64.pyd', 'momentsPen.py', 'perimeterPen.py', 'pointInsidePen.py', 'pointPen.py', 'qtPen.py', 'qu2cuPen.py', 'quartzPen.py', 'recordingPen.py', 'reportLabPen.py', 'reverseContourPen.py', 'roundingPen.py', 'statisticsPen.py', 'svgPathPen.py', 't2CharStringPen.py', 'teePen.py', 'transformPen.py', 'ttGlyphPen.py', 'wxPen.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\qu2cu ['benchmark.py', 'cli.py', 'qu2cu.c', 'qu2cu.cp311-win_amd64.pyd', 'qu2cu.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\subset ['cff.py', 'svg.py', 'util.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\svgLib ['__init__.py']
# .\.venv\Lib\site-packages\fontTools\svgLib\path ['arc.py', 'parser.py', 'shapes.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\t1Lib ['__init__.py']
# .\.venv\Lib\site-packages\fontTools\ttLib ['macUtils.py', 'removeOverlaps.py', 'reorderGlyphs.py', 'scaleUpem.py', 'sfnt.py', 'standardGlyphOrder.py', 'ttCollection.py', 'ttFont.py', 'ttGlyphSet.py', 'ttVisitor.py', 'woff2.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\ttLib\tables ['asciiTable.py', 'BitmapGlyphMetrics.py', 'B_A_S_E_.py', 'C_B_D_T_.py', 'C_B_L_C_.py', 'C_F_F_.py', 'C_F_F__2.py', 'C_O_L_R_.py', 'C_P_A_L_.py', 'DefaultTable.py', 'D_S_I_G_.py', 'D__e_b_g.py', 'E_B_D_T_.py', 'E_B_L_C_.py', 'F_F_T_M_.py', 'F__e_a_t.py', 'grUtils.py', 'G_D_E_F_.py', 'G_P_O_S_.py', 'G_S_U_B_.py', 'G_V_A_R_.py', 'G__l_a_t.py', 'G__l_o_c.py', 'H_V_A_R_.py', 'J_S_T_F_.py', 'L_T_S_H_.py', 'M_A_T_H_.py', 'M_V_A_R_.py', 'otBase.py', 'otConverters.py', 'otData.py', 'otTables.py', 'otTraverse.py', 'O_S_2f_2.py', 'sbixGlyph.py', 'sbixStrike.py', 'S_T_A_T_.py', 'S_V_G_.py', 'S__i_l_f.py', 'S__i_l_l.py', 'table_API_readme.txt', 'ttProgram.py', 'TupleVariation.py', 'T_S_I_B_.py', 'T_S_I_C_.py', 'T_S_I_D_.py', 'T_S_I_J_.py', 'T_S_I_P_.py', 'T_S_I_S_.py', 'T_S_I_V_.py', 'T_S_I__0.py', 'T_S_I__1.py', 'T_S_I__2.py', 'T_S_I__3.py', 'T_S_I__5.py', 'T_T_F_A_.py', 'V_A_R_C_.py', 'V_D_M_X_.py', 'V_O_R_G_.py', 'V_V_A_R_.py', '_a_n_k_r.py', '_a_v_a_r.py', '_b_s_l_n.py', '_c_i_d_g.py', '_c_m_a_p.py', '_c_v_a_r.py', '_c_v_t.py', '_f_e_a_t.py', '_f_p_g_m.py', '_f_v_a_r.py', '_g_a_s_p.py', '_g_c_i_d.py', '_g_l_y_f.py', '_g_v_a_r.py', '_h_d_m_x.py', '_h_e_a_d.py', '_h_h_e_a.py', '_h_m_t_x.py', '_k_e_r_n.py', '_l_c_a_r.py', '_l_o_c_a.py', '_l_t_a_g.py', '_m_a_x_p.py', '_m_e_t_a.py', '_m_o_r_t.py', '_m_o_r_x.py', '_n_a_m_e.py', '_o_p_b_d.py', '_p_o_s_t.py', '_p_r_e_p.py', '_p_r_o_p.py', '_s_b_i_x.py', '_t_r_a_k.py', '_v_h_e_a.py', '_v_m_t_x.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\ufoLib ['converters.py', 'errors.py', 'etree.py', 'filenames.py', 'glifLib.py', 'kerning.py', 'plistlib.py', 'pointPen.py', 'utils.py', 'validators.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\unicodedata ['Blocks.py', 'Mirrored.py', 'OTTags.py', 'ScriptExtensions.py', 'Scripts.py', '__init__.py']
# .\.venv\Lib\site-packages\fontTools\varLib ['avarPlanner.py', 'builder.py', 'cff.py', 'errors.py', 'featureVars.py', 'hvar.py', 'interpolatable.py', 'interpolatableHelpers.py', 'interpolatablePlot.py', 'interpolatableTestContourOrder.py', 'interpolatableTestStartingPoint.py', 'interpolate_layout.py', 'iup.c', 'iup.cp311-win_amd64.pyd', 'iup.py', 'merger.py', 'models.py', 'multiVarStore.py', 'mutator.py', 'mvar.py', 'plot.py', 'stat.py', 'varStore.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\varLib\avar ['build.py', 'map.py', 'plan.py', 'unbuild.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\varLib\instancer ['featureVars.py', 'names.py', 'solver.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fontTools\voltLib ['ast.py', 'error.py', 'lexer.py', 'parser.py', 'voltToFea.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\fonttools-4.62.1.dist-info ['entry_points.txt', 'INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\fonttools-4.62.1.dist-info\licenses ['LICENSE', 'LICENSE.external']
# .\.venv\Lib\site-packages\fsspec ['archive.py', 'asyn.py', 'caching.py', 'callbacks.py', 'compression.py', 'config.py', 'conftest.py', 'core.py', 'dircache.py', 'exceptions.py', 'fuse.py', 'generic.py', 'gui.py', 'json.py', 'mapping.py', 'parquet.py', 'registry.py', 'spec.py', 'transaction.py', 'utils.py', '_version.py', '__init__.py']
# .\.venv\Lib\site-packages\fsspec\implementations ['arrow.py', 'asyn_wrapper.py', 'cached.py', 'cache_mapper.py', 'cache_metadata.py', 'chained.py', 'dask.py', 'data.py', 'dbfs.py', 'dirfs.py', 'ftp.py', 'gist.py', 'git.py', 'github.py', 'http.py', 'http_sync.py', 'jupyter.py', 'libarchive.py', 'local.py', 'memory.py', 'reference.py', 'sftp.py', 'smb.py', 'tar.py', 'webhdfs.py', 'zip.py', '__init__.py']
# .\.venv\Lib\site-packages\fsspec\tests []
# .\.venv\Lib\site-packages\fsspec\tests\abstract ['common.py', 'copy.py', 'get.py', 'mv.py', 'open.py', 'pipe.py', 'put.py', '__init__.py']
# .\.venv\Lib\site-packages\fsspec-2026.2.0.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'WHEEL']
# .\.venv\Lib\site-packages\fsspec-2026.2.0.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\functorch ['__init__.py']
# .\.venv\Lib\site-packages\functorch\compile ['__init__.py']
# .\.venv\Lib\site-packages\functorch\dim ['magic_trace.py', 'op_properties.py', 'wrap_type.py', '_dim_entry.py', '_enable_all_layers.py', '_getsetitem.py', '_order.py', '_py_inst_decoder.py', '_tensor_info.py', '_wrap.py', '__init__.py']
# .\.venv\Lib\site-packages\functorch\einops ['rearrange.py', '_parsing.py', '__init__.py']
# .\.venv\Lib\site-packages\functorch\experimental ['control_flow.py', 'ops.py', '__init__.py']
# .\.venv\Lib\site-packages\functorch\_src ['__init__.py']
# .\.venv\Lib\site-packages\functorch\_src\aot_autograd ['__init__.py']
# .\.venv\Lib\site-packages\functorch\_src\eager_transforms ['__init__.py']
# .\.venv\Lib\site-packages\functorch\_src\make_functional ['__init__.py']
# .\.venv\Lib\site-packages\functorch\_src\vmap ['__init__.py']
# .\.venv\Lib\site-packages\iniconfig ['exceptions.py', 'py.typed', '_parse.py', '_version.py', '__init__.py']
# .\.venv\Lib\site-packages\iniconfig-2.3.0.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\iniconfig-2.3.0.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\ipykernel ['compiler.py', 'connect.py', 'control.py', 'debugger.py', 'displayhook.py', 'embed.py', 'eventloops.py', 'heartbeat.py', 'iostream.py', 'ipkernel.py', 'jsonutil.py', 'kernelapp.py', 'kernelbase.py', 'kernelspec.py', 'log.py', 'parentpoller.py', 'py.typed', 'shellchannel.py', 'socket_pair.py', 'subshell.py', 'subshell_manager.py', 'thread.py', 'trio_runner.py', 'utils.py', 'zmqshell.py', '_eventloop_macos.py', '_version.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\ipykernel\comm ['comm.py', 'manager.py', '__init__.py']
# .\.venv\Lib\site-packages\ipykernel\comm\__pycache__ ['comm.cpython-311.pyc', 'manager.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\ipykernel\gui ['gtk3embed.py', 'gtkembed.py', '__init__.py']
# .\.venv\Lib\site-packages\ipykernel\inprocess ['blocking.py', 'channels.py', 'client.py', 'constants.py', 'ipkernel.py', 'manager.py', 'socket.py', '__init__.py']
# .\.venv\Lib\site-packages\ipykernel\pylab ['backend_inline.py', 'config.py', '__init__.py']
# .\.venv\Lib\site-packages\ipykernel\resources ['logo-32x32.png', 'logo-64x64.png', 'logo-svg.svg']
# .\.venv\Lib\site-packages\ipykernel\__pycache__ ['compiler.cpython-311.pyc', 'connect.cpython-311.pyc', 'control.cpython-311.pyc', 'debugger.cpython-311.pyc', 'displayhook.cpython-311.pyc', 'eventloops.cpython-311.pyc', 'heartbeat.cpython-311.pyc', 'iostream.cpython-311.pyc', 'ipkernel.cpython-311.pyc', 'jsonutil.cpython-311.pyc', 'kernelapp.cpython-311.pyc', 'kernelbase.cpython-311.pyc', 'parentpoller.cpython-311.pyc', 'shellchannel.cpython-311.pyc', 'socket_pair.cpython-311.pyc', 'subshell.cpython-311.pyc', 'subshell_manager.cpython-311.pyc', 'thread.cpython-311.pyc', 'utils.cpython-311.pyc', 'zmqshell.cpython-311.pyc', '_version.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\ipykernel-7.2.0.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'WHEEL']
# .\.venv\Lib\site-packages\ipykernel-7.2.0.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\IPython ['display.py', 'paths.py', 'py.typed', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\IPython\core ['alias.py', 'application.py', 'async_helpers.py', 'autocall.py', 'builtin_trap.py', 'compilerop.py', 'completer.py', 'completerlib.py', 'crashhandler.py', 'debugger.py', 'debugger_backport.py', 'display.py', 'displayhook.py', 'displaypub.py', 'display_functions.py', 'display_trap.py', 'doctb.py', 'error.py', 'events.py', 'extensions.py', 'formatters.py', 'getipython.py', 'guarded_eval.py', 'history.py', 'historyapp.py', 'hooks.py', 'inputtransformer2.py', 'interactiveshell.py', 'latex_symbols.py', 'logger.py', 'macro.py', 'magic.py', 'magic_arguments.py', 'oinspect.py', 'page.py', 'payload.py', 'payloadpage.py', 'prefilter.py', 'profileapp.py', 'profiledir.py', 'pylabtools.py', 'release.py', 'shellapp.py', 'splitinput.py', 'tbtools.py', 'tips.py', 'ultratb.py', 'usage.py', '__init__.py']
# .\.venv\Lib\site-packages\IPython
cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\jedi\plugins ['django.py', 'flask.py', 'pytest.py', 'registry.py', 'stdlib.py', '__init__.py']
# .\.venv\Lib\site-packages\jedi\plugins\__pycache__ ['django.cpython-311.pyc', 'flask.cpython-311.pyc', 'pytest.cpython-311.pyc', 'registry.cpython-311.pyc', 'stdlib.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\jedi\third_party []
# .\.venv\Lib\site-packages\jedi\third_party\django-stubs ['LICENSE.txt']
# .\.venv\Lib\site-packages\jedi\third_party\django-stubs\django-stubs ['shortcuts.pyi', '__init__.pyi']
# .\.venv\Lib\site-packages\jedi\third_party\django-stubs\django-stubs\apps ['config.pyi', 'registry.pyi', '__init__.pyi']
# .\.venv\Lib\site-packages\jedi\third_party\django-stubs\django-stubs\conf ['global_settings.pyi', '__init__.pyi']
# .\.venv\Lib\site-packages\jedi\third_party\django-stubs\django-stubs\conf\locale ['__init__.pyi']
# .\.venv\Lib\site-packages\jedi\third_party\django-stubs\django-stubs\conf\urls ['i18n.pyi', 'static.pyi', '__init__.pyi']
# .\.venv\Lib\site-packages\jedi\third_party\django-stubs\django-stubs\contrib ['__init__.pyi']
# ...
# .\.venv\Lib\site-packages\tzdata\zoneinfo\Brazil ['Acre', 'DeNoronha', 'East', 'West', '__init__.py']
# .\.venv\Lib\site-packages\tzdata\zoneinfo\Canada ['Atlantic', 'Central', 'Eastern', 'Mountain', 'Newfoundland', 'Pacific', 'Saskatchewan', 'Yukon', '__init__.py']
# .\.venv\Lib\site-packages\tzdata\zoneinfo\Chile ['Continental', 'EasterIsland', '__init__.py']
# .\.venv\Lib\site-packages\tzdata\zoneinfo\Etc ['GMT', 'GMT+0', 'GMT+1', 'GMT+10', 'GMT+11', 'GMT+12', 'GMT+2', 'GMT+3', 'GMT+4', 'GMT+5', 'GMT+6', 'GMT+7', 'GMT+8', 'GMT+9', 'GMT-0', 'GMT-1', 'GMT-10', 'GMT-11', 'GMT-12', 'GMT-13', 'GMT-14', 'GMT-2', 'GMT-3', 'GMT-4', 'GMT-5', 'GMT-6', 'GMT-7', 'GMT-8', 'GMT-9', 'GMT0', 'Greenwich', 'UCT', 'Universal', 'UTC', 'Zulu', '__init__.py']
# .\.venv\Lib\site-packages\tzdata\zoneinfo\Europe ['Amsterdam', 'Andorra', 'Astrakhan', 'Athens', 'Belfast', 'Belgrade', 'Berlin', 'Bratislava', 'Brussels', 'Bucharest', 'Budapest', 'Busingen', 'Chisinau', 'Copenhagen', 'Dublin', 'Gibraltar', 'Guernsey', 'Helsinki', 'Isle_of_Man', 'Istanbul', 'Jersey', 'Kaliningrad', 'Kiev', 'Kirov', 'Kyiv', 'Lisbon', 'Ljubljana', 'London', 'Luxembourg', 'Madrid', 'Malta', 'Mariehamn', 'Minsk', 'Monaco', 'Moscow', 'Nicosia', 'Oslo', 'Paris', 'Podgorica', 'Prague', 'Riga', 'Rome', 'Samara', 'San_Marino', 'Sarajevo', 'Saratov', 'Simferopol', 'Skopje', 'Sofia', 'Stockholm', 'Tallinn', 'Tirane', 'Tiraspol', 'Ulyanovsk', 'Uzhgorod', 'Vaduz', 'Vatican', 'Vienna', 'Vilnius', 'Volgograd', 'Warsaw', 'Zagreb', 'Zaporozhye', 'Zurich', '__init__.py']
# .\.venv\Lib\site-packages\tzdata\zoneinfo\Indian ['Antananarivo', 'Chagos', 'Christmas', 'Cocos', 'Comoro', 'Kerguelen', 'Mahe', 'Maldives', 'Mauritius', 'Mayotte', 'Reunion', '__init__.py']
# .\.venv\Lib\site-packages\tzdata\zoneinfo\Mexico ['BajaNorte', 'BajaSur', 'General', '__init__.py']
# .\.venv\Lib\site-packages\tzdata\zoneinfo\Pacific ['Apia', 'Auckland', 'Bougainville', 'Chatham', 'Chuuk', 'Easter', 'Efate', 'Enderbury', 'Fakaofo', 'Fiji', 'Funafuti', 'Galapagos', 'Gambier', 'Guadalcanal', 'Guam', 'Honolulu', 'Johnston', 'Kanton', 'Kiritimati', 'Kosrae', 'Kwajalein', 'Majuro', 'Marquesas', 'Midway', 'Nauru', 'Niue', 'Norfolk', 'Noumea', 'Pago_Pago', 'Palau', 'Pitcairn', 'Pohnpei', 'Ponape', 'Port_Moresby', 'Rarotonga', 'Saipan', 'Samoa', 'Tahiti', 'Tarawa', 'Tongatapu', 'Truk', 'Wake', 'Wallis', 'Yap', '__init__.py']
# .\.venv\Lib\site-packages\tzdata\zoneinfo\US ['Alaska', 'Aleutian', 'Arizona', 'Central', 'East-Indiana', 'Eastern', 'Hawaii', 'Indiana-Starke', 'Michigan', 'Mountain', 'Pacific', 'Samoa', '__init__.py']
# .\.venv\Lib\site-packages\tzdata-2025.3.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\tzdata-2025.3.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\tzdata-2025.3.dist-info\licenses\licenses ['LICENSE_APACHE']
# .\.venv\Lib\site-packages\wcwidth ['bisearch.py', 'control_codes.py', 'escape_sequences.py', 'grapheme.py', 'py.typed', 'sgr_state.py', 'table_ambiguous.py', 'table_grapheme.py', 'table_mc.py', 'table_vs16.py', 'table_wide.py', 'table_zero.py', 'textwrap.py', 'unicode_versions.py', 'wcwidth.py', '__init__.py']
# .\.venv\Lib\site-packages\wcwidth\__pycache__ ['bisearch.cpython-311.pyc', 'control_codes.cpython-311.pyc', 'escape_sequences.cpython-311.pyc', 'grapheme.cpython-311.pyc', 'sgr_state.cpython-311.pyc', 'table_ambiguous.cpython-311.pyc', 'table_grapheme.cpython-311.pyc', 'table_mc.cpython-311.pyc', 'table_vs16.cpython-311.pyc', 'table_wide.cpython-311.pyc', 'table_zero.cpython-311.pyc', 'textwrap.cpython-311.pyc', 'unicode_versions.cpython-311.pyc', 'wcwidth.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\wcwidth-0.6.0.dist-info ['INSTALLER', 'METADATA', 'RECORD', 'REQUESTED', 'WHEEL']
# .\.venv\Lib\site-packages\wcwidth-0.6.0.dist-info\licenses ['LICENSE']
# .\.venv\Lib\site-packages\webencodings ['labels.py', 'mklabels.py', 'tests.py', 'x_user_defined.py', '__init__.py']
# .\.venv\Lib\site-packages\webencodings-0.5.1.dist-info ['DESCRIPTION.rst', 'INSTALLER', 'METADATA', 'metadata.json', 'RECORD', 'REQUESTED', 'top_level.txt', 'WHEEL']
# .\.venv\Lib\site-packages\zmq ['asyncio.py', 'constants.py', 'decorators.py', 'error.py', 'py.typed', '_future.py', '_future.pyi', '_typing.py', '__init__.pxd', '__init__.py', '__init__.pyi']
# .\.venv\Lib\site-packages\zmq\auth ['asyncio.py', 'base.py', 'certs.py', 'ioloop.py', 'thread.py', '__init__.py']
# .\.venv\Lib\site-packages\zmq\backend ['select.py', '__init__.py', '__init__.pyi']
# .\.venv\Lib\site-packages\zmq\backend\cffi ['context.py', 'devices.py', 'error.py', 'message.py', 'README.md', 'socket.py', 'utils.py', '_cdefs.h', '_cffi_src.c', '_poll.py', '__init__.py']
# .\.venv\Lib\site-packages\zmq\backend\cython ['constant_enums.pxi', 'libzmq.pxd', '_externs.pxd', '_zmq.cp311-win_amd64.pyd', '_zmq.pxd', '_zmq.py', '__init__.pxd', '__init__.py']
# .\.venv\Lib\site-packages\zmq\backend\cython\__pycache__ ['__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\zmq\backend\__pycache__ ['select.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\zmq\devices ['basedevice.py', 'monitoredqueue.py', 'monitoredqueuedevice.py', 'proxydevice.py', 'proxysteerabledevice.py', '__init__.py']
# .\.venv\Lib\site-packages\zmq\eventloop ['future.py', 'ioloop.py', 'zmqstream.py', '_deprecated.py', '__init__.py']
# .\.venv\Lib\site-packages\zmq\eventloop\__pycache__ ['zmqstream.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\zmq\green ['core.py', 'device.py', 'poll.py', '__init__.py']
# .\.venv\Lib\site-packages\zmq\green\eventloop ['ioloop.py', 'zmqstream.py', '__init__.py']
# .\.venv\Lib\site-packages\zmq\log ['handlers.py', '__init__.py', '__main__.py']
# .\.venv\Lib\site-packages\zmq\ssh ['forward.py', 'tunnel.py', '__init__.py']
# .\.venv\Lib\site-packages\zmq\sugar ['attrsettr.py', 'context.py', 'frame.py', 'poll.py', 'socket.py', 'stopwatch.py', 'tracker.py', 'version.py', '__init__.py', '__init__.pyi']
# .\.venv\Lib\site-packages\zmq\sugar\__pycache__ ['attrsettr.cpython-311.pyc', 'context.cpython-311.pyc', 'frame.cpython-311.pyc', 'poll.cpython-311.pyc', 'socket.cpython-311.pyc', 'stopwatch.cpython-311.pyc', 'tracker.cpython-311.pyc', 'version.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\zmq\tests ['__init__.py']
# .\.venv\Lib\site-packages\zmq\utils ['garbage.py', 'getpid_compat.h', 'interop.py', 'ipcmaxlen.h', 'jsonapi.py', 'monitor.py', 'mutex.h', 'pyversion_compat.h', 'strtypes.py', 'win32.py', 'z85.py', 'zmq_compat.h', '__init__.py']
# .\.venv\Lib\site-packages\zmq\utils\__pycache__ ['interop.cpython-311.pyc', 'jsonapi.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\zmq\__pycache__ ['asyncio.cpython-311.pyc', 'constants.cpython-311.pyc', 'error.cpython-311.pyc', '_future.cpython-311.pyc', '_typing.cpython-311.pyc', '__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\_distutils_hack ['override.py', '__init__.py']
# .\.venv\Lib\site-packages\_distutils_hack\__pycache__ ['__init__.cpython-311.pyc']
# .\.venv\Lib\site-packages\_pytest ['cacheprovider.py', 'capture.py', 'compat.py', 'debugging.py', 'deprecated.py', 'doctest.py', 'faulthandler.py', 'fixtures.py', 'freeze_support.py', 'helpconfig.py', 'hookspec.py', 'junitxml.py', 'legacypath.py', 'logging.py', 'main.py', 'monkeypatch.py', 'nodes.py', 'outcomes.py', 'pastebin.py', 'pathlib.py', 'py.typed', 'pytester.py', 'pytester_assertions.py', 'python.py', 'python_api.py', 'raises.py', 'recwarn.py', 'reports.py', 'runner.py', 'scope.py', 'setuponly.py', 'setupplan.py', 'skipping.py', 'stash.py', 'stepwise.py', 'subtests.py', 'terminal.py', 'terminalprogress.py', 'threadexception.py', 'timing.py', 'tmpdir.py', 'tracemalloc.py', 'unittest.py', 'unraisableexception.py', 'warnings.py', 'warning_types.py', '_argcomplete.py', '_version.py', '__init__.py']
# .\.venv\Lib\site-packages\_pytest\assertion ['rewrite.py', 'truncate.py', 'util.py', '__init__.py']
# .\.venv\Lib\site-packages\_pytest\config ['argparsing.py', 'compat.py', 'exceptions.py', 'findpaths.py', '__init__.py']
# .\.venv\Lib\site-packages\_pytest\mark ['expression.py', 'structures.py', '__init__.py']
# .\.venv\Lib\site-packages\_pytest\_code ['code.py', 'source.py', '__init__.py']
# .\.venv\Lib\site-packages\_pytest\_io ['pprint.py', 'saferepr.py', 'terminalwriter.py', 'wcwidth.py', '__init__.py']
# .\.venv\Lib\site-packages\_pytest\_py ['error.py', 'path.py', '__init__.py']
# .\.venv\Lib\site-packages\__pycache__ ['decorator.cpython-311.pyc', 'ipykernel_launcher.cpython-311.pyc', 'six.cpython-311.pyc', 'typing_extensions.cpython-311.pyc', '_virtualenv.cpython-311.pyc']
# .\.venv\Scripts ['activate', 'activate.bat', 'activate.csh', 'activate.fish', 'activate.nu', 'activate.ps1', 'activate_this.py', 'deactivate.bat', 'debugpy-adapter.exe', 'debugpy.exe', 'f2py.exe', 'fonttools.exe', 'ipython.exe', 'ipython3.exe', 'isympy.exe', 'jsonschema.exe', 'jupyter-dejavu.exe', 'jupyter-execute.exe', 'jupyter-kernel.exe', 'jupyter-kernelspec.exe', 'jupyter-migrate.exe', 'jupyter-nbconvert.exe', 'jupyter-run.exe', 'jupyter-troubleshoot.exe', 'jupyter-trust.exe', 'jupyter.exe', 'numpy-config.exe', 'py.test.exe', 'pydoc.bat', 'pyftmerge.exe', 'pyftsubset.exe', 'pygmentize.exe', 'pytest.exe', 'python.exe', 'pythonw.exe', 'ruff.exe', 'torchfrtrace.exe', 'torchrun.exe', 'ttx.exe']
# .\.venv\share []
# .\.venv\share\jupyter []
# .\.venv\share\jupyter\kernels []
# .\.venv\share\jupyter\kernels\python3 ['kernel.json', 'logo-32x32.png', 'logo-64x64.png', 'logo-svg.svg']
# .\.venv\share\jupyter\labextensions []
# .\.venv\share\jupyter\labextensions\jupyterlab_pygments ['install.json', 'package.json']
# .\.venv\share\jupyter\labextensions\jupyterlab_pygments\static ['568.1e2faa2ba0bbe59c4780.js', '747.67662283a5707eeb4d4c.js', 'remoteEntry.5cbb9d2323598fbda535.js', 'style.js', 'third-party-licenses.json']
# .\.venv\share\jupyter\nbconvert []
# .\.venv\share\jupyter\nbconvert\templates []
# .\.venv\share\jupyter\nbconvert\templates\asciidoc ['conf.json', 'index.asciidoc.j2']
# .\.venv\share\jupyter\nbconvert\templates\base ['celltags.j2', 'cell_id_anchor.j2', 'display_priority.j2', 'jupyter_widgets.html.j2', 'mathjax.html.j2', 'null.j2']
# .\.venv\share\jupyter\nbconvert\templates\basic ['conf.json', 'index.html.j2']
# .\.venv\share\jupyter\nbconvert\templates\classic ['base.html.j2', 'conf.json', 'index.html.j2']
# .\.venv\share\jupyter\nbconvert\templates\classic\static ['style.css']
# .\.venv\share\jupyter\nbconvert\templates\compatibility ['display_priority.tpl', 'full.tpl']
# .\.venv\share\jupyter\nbconvert\templates\lab ['base.html.j2', 'conf.json', 'index.html.j2', 'mermaidjs.html.j2']
# .\.venv\share\jupyter\nbconvert\templates\lab\static ['index.css', 'theme-dark.css', 'theme-light.css']
# .\.venv\share\jupyter\nbconvert\templates\latex ['base.tex.j2', 'conf.json', 'display_priority.j2', 'document_contents.tex.j2', 'index.tex.j2', 'null.j2', 'report.tex.j2', 'style_bw_ipython.tex.j2', 'style_bw_python.tex.j2', 'style_ipython.tex.j2', 'style_jupyter.tex.j2', 'style_python.tex.j2']
# .\.venv\share\jupyter\nbconvert\templates\markdown ['conf.json', 'index.md.j2']
# .\.venv\share\jupyter\nbconvert\templates\python ['conf.json', 'index.py.j2']
# .\.venv\share\jupyter\nbconvert\templates\reveal ['base.html.j2', 'cellslidedata.j2', 'conf.json', 'index.html.j2']
# .\.venv\share\jupyter\nbconvert\templates\reveal\static ['custom_reveal.css']
# .\.venv\share\jupyter\nbconvert\templates\rst ['conf.json', 'index.rst.j2']
# .\.venv\share\jupyter\nbconvert\templates\script ['conf.json', 'script.j2']
# .\.venv\share\jupyter\nbconvert\templates\webpdf ['conf.json', 'index.pdf.j2']
# .\.venv\share\man []
# .\.venv\share\man\man1 ['ipython.1', 'isympy.1', 'ttx.1']
# .\data []
# .\data\test []
# .\data\test\cat ['cat_0009.jpg', 'cat_0010.jpg']
# .\data\test\dog ['dog_0009.jpg', 'dog_0010.jpg']
# .\data\train []
# .\data\train\cat ['cat_0001.jpg', 'cat_0002.jpg', 'cat_0003.jpg', 'cat_0004.jpg', 'cat_0005.jpg', 'cat_0006.jpg']
# .\data\train\dog ['dog_0001.jpg', 'dog_0002.jpg', 'dog_0003.jpg', 'dog_0004.jpg', 'dog_0005.jpg', 'dog_0006.jpg']
# .\data\val []
# .\data\val\cat ['cat_0007.jpg', 'cat_0008.jpg']
# .\data\val\dog ['dog_0007.jpg', 'dog_0008.jpg']
# .\lab_utils ['convert_notebook.py', 'format_report.py', 'visualization.py', '__init__.py']
# .\tests ['test_notebook.py']
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[54], line 11
#       7     print(root, files)
#       9 # Load the CSV file.
#      10 # Adjust the path if needed.
# ---> 11 df = pd.read_csv("labs/datasaurus.csv")
#      13 print("Shape:", df.shape)
#      14 display(df.head())
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\io\common.py:926, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     921 elif isinstance(handle, str):
#     922     # Check whether the filename is to be opened in binary mode.
#     923     # Binary mode does not support 'encoding' and 'newline'.
#     924     if ioargs.encoding and "b" not in ioargs.mode:
#     925         # Encoding
# --> 926         handle = open(
#     927             handle,
#     928             ioargs.mode,
#     929             encoding=ioargs.encoding,
#     930             errors=errors,
#     931             newline="",
#     932         )
#     933     else:
#     934         # Binary mode
#     935         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'labs/datasaurus.csv'

# %%
# Check the column names and data types.

print("Columns:", df.columns.tolist())
print("\nData types:")
print(df.dtypes)

print("\nMissing values:")
print(df.isna().sum())
# Out:
# Columns: ['name', 'label', 'score', 'high_score', 'score_scaled']
#
# Data types:
# name                str
# label               str
# score           float64
# high_score         bool
# score_scaled    float64
# dtype: object
#
# Missing values:
# name            0
# label           0
# score           0
# high_score      0
# score_scaled    0
# dtype: int64

# %%
# Overall summary statistics for x and y.

display(df[["x", "y"]].describe())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 3
#       1 # Overall summary statistics for x and y.
# ----> 3 display(df[["x", "y"]].describe())
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\core\frame.py:4384, in DataFrame.__getitem__(self, key)
#    4382     if is_iterator(key):
#    4383         key = list(key)
# -> 4384     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    4386 # take() does not accept boolean indexers
#    4387 if getattr(indexer, "dtype", None) == bool:
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\core\indexes\base.py:6302, in Index._get_indexer_strict(self, key, axis_name)
#    6299 else:
#    6300     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6302 self._raise_if_missing(keyarr, indexer, axis_name)
#    6304 keyarr = self.take(indexer)
#    6305 if isinstance(key, Index):
#    6306     # GH 42790 - Preserve name from an Index
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\core\indexes\base.py:6352, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6350 if nmissing:
#    6351     if nmissing == len(indexer):
# -> 6352         raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6354     not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6355     raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['x', 'y'], dtype='str')] are in the [columns]"

# %%
# Summary statistics for each dataset group. 
# As you can see, all the groups have the same summary statistics..

group_stats = df.groupby("dataset")[["x", "y"]].agg(["mean", "std", "min", "max", "median"])
display(group_stats)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[41], line 4
#       1 # Summary statistics for each dataset group.
#       2 # As you can see, all the groups have the same summary statistics..
# ----> 4 group_stats = df.groupby("dataset")[["x", "y"]].agg(["mean", "std", "min", "max", "median"])
#       5 display(group_stats)
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\util\_decorators.py:336, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     330 if len(args) > num_allow_args:
#     331     warnings.warn(
#     332         msg.format(arguments=_format_argument_list(allow_args)),
#     333         klass,
#     334         stacklevel=find_stack_level(),
#     335     )
# --> 336 return func(*args, **kwargs)
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\core\frame.py:10817, in DataFrame.groupby(self, by, level, as_index, sort, group_keys, observed, dropna)
#   10814 if level is None and by is None:
#   10815     raise TypeError("You have to supply one of 'by' and 'level'")
# > 10817 return DataFrameGroupBy(
#   10818     obj=self,
#   10819     keys=by,
#   10820     level=level,
#   10821     as_index=as_index,
#   10822     sort=sort,
#   10823     group_keys=group_keys,
#   10824     observed=observed,
#   10825     dropna=dropna,
#   10826 )
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\core\groupby\groupby.py:1095, in GroupBy.__init__(self, obj, keys, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1092 self.dropna = dropna
#    1094 if grouper is None:
# -> 1095     grouper, exclusions, obj = get_grouper(
#    1096         obj,
#    1097         keys,
#    1098         level=level,
#    1099         sort=sort,
#    1100         observed=observed,
#    1101         dropna=self.dropna,
#    1102     )
#    1104 self.observed = observed
#    1105 self.obj = obj
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\core\groupby\grouper.py:901, in get_grouper(obj, key, level, sort, observed, validate, dropna)
#     899         in_axis, level, gpr = False, gpr, None
#     900     else:
# --> 901         raise KeyError(gpr)
#     902 elif isinstance(gpr, Grouper) and gpr.key is not None:
#     903     # Add key to exclusions
#     904     exclusions.add(gpr.key)
#
# KeyError: 'dataset'

# %%
# Plot all datasets in a grid.

datasets = df["dataset"].unique()
n_plots = len(datasets)
ncols = 4
nrows = int(np.ceil(n_plots / ncols))

fig, axes = plt.subplots(nrows, ncols, figsize=(14, 10))
axes = np.array(axes).reshape(-1)

for ax, name in zip(axes, datasets):
    subset = df[df["dataset"] == name]
    ax.scatter(subset["x"], subset["y"], s=10)
    ax.set_title(name)
    ax.set_xticks([])
    ax.set_yticks([])
    ax.set_aspect("equal", adjustable="box")

# Hide unused subplots
for ax in axes[n_plots:]:
    ax.axis("off")

plt.suptitle("Datasaurus Dozen", fontsize=16)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:197, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7668, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7676, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'dataset'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[45], line 3
#       1 # Plot all datasets in a grid.
# ----> 3 datasets = df["dataset"].unique()
#       4 n_plots = len(datasets)
#       5 ncols = 4
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\core\frame.py:4378, in DataFrame.__getitem__(self, key)
#    4376 if self.columns.nlevels > 1:
#    4377     return self._getitem_multilevel(key)
# -> 4378 indexer = self.columns.get_loc(key)
#    4379 if is_integer(indexer):
#    4380     indexer = [indexer]
#
# File d:\Year 2\Intro_to_DS_and_AI\lab-2-pandas-QuillenCookies\.venv\Lib\site-packages\pandas\core\indexes\base.py:3648, in Index.get_loc(self, key)
#    3643     if isinstance(casted_key, slice) or (
#    3644         isinstance(casted_key, abc.Iterable)
#    3645         and any(isinstance(x, slice) for x in casted_key)
#    3646     ):
#    3647         raise InvalidIndexError(key) from err
# -> 3648     raise KeyError(key) from err
#    3649 except TypeError:
#    3650     # If we have a listlike key, _check_indexing_error will raise
#    3651     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3652     #  the TypeError.
#    3653     self._check_indexing_error(key)
#
# KeyError: 'dataset'

# %% [markdown]
# ### Reflection
#
# The summary statistics may look similar across datasets, but the plots can be very different.
#
# This is why EDA should always include both:
# - numerical summaries
# - visual inspection
